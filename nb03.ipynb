# %%
state_codes = [
    "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA",
    "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD",
    "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ",
    "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC",
    "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
]

state_names = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California",
    "Colorado", "Connecticut", "Delaware", "Florida", "Georgia",
    "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas",
    "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts",
    "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana",
    "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico",
    "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma",
    "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota",
    "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington",
    "West Virginia", "Wisconsin", "Wyoming"
]

# %%
from scrapy import Selector
medians =[]
j =0
for state in state_codes:
   
    populationurl= 'https://www.census.gov/quickfacts/fact/table/'+state+'/INC110221#INC110221'
   
    response = requests.get(populationurl)
    sel= Selector(text=response.text)
    medians.append(sel.css('td::text').getall()[3])
    
   
    



caurl='https://www.census.gov/quickfacts/fact/table/WI/INC110221#INC110221'
# Out:
# AL
# https://www.census.gov/quickfacts/fact/table/AL/INC110221#INC110221
# $54,943
# AK
# https://www.census.gov/quickfacts/fact/table/AK/INC110221#INC110221
# $80,287
# AZ
# https://www.census.gov/quickfacts/fact/table/AZ/INC110221#INC110221
# $65,913
# AR
# https://www.census.gov/quickfacts/fact/table/AR/INC110221#INC110221
# $52,123
# CA
# https://www.census.gov/quickfacts/fact/table/CA/INC110221#INC110221
# $84,097
# CO
# https://www.census.gov/quickfacts/fact/table/CO/INC110221#INC110221
# $80,184
# CT
# https://www.census.gov/quickfacts/fact/table/CT/INC110221#INC110221
# $83,572
# DE
# https://www.census.gov/quickfacts/fact/table/DE/INC110221#INC110221
# $72,724
# FL
# https://www.census.gov/quickfacts/fact/table/FL/INC110221#INC110221
# $61,777
# GA
# https://www.census.gov/quickfacts/fact/table/GA/INC110221#INC110221
# $65,030
# HI
# https://www.census.gov/quickfacts/fact/table/HI/INC110221#INC110221
# $88,005
# ID
# ...

# %%
caurl='https://www.census.gov/quickfacts/fact/table/CA/INC110221#INC110221'
response = requests.get(caurl)
sel= Selector(text=response.text)


median= sel.xpath("//td['data-value']").getall()

print(median)
# Out:
# ['<td>\n<a class="quickinfo icon-info-circled-1" data-title="Median household income (in 2021 dollars), 2017-2021" title="Quick Info: Sources, Definitions, Methodology" tabindex="-1" target="_blank" href="/quickfacts/note/INC110221"></a><span>Median household income (in 2021 dollars), 2017-2021</span>\n</td>', '<td data-geoid="06" data-isnumeric="1" data-value="84097" data-srcnote="false">\n<span data-title="California"></span>$84,097</td>', '<td>\n<a class="quickinfo icon-info-circled-1" data-title="Population Estimates, July 1, 2022, (V2022)" title="Quick Info: Sources, Definitions, Methodology" tabindex="-1" id="PST045222" target="_blank" href="/quickfacts/note/PST045222"></a><span>Population Estimates, July 1, 2022, (V2022)</span>\n</td>', '<td data-geoid="06" data-isnumeric="1" data-value="39029342" data-srcnote="true">\n<span data-title="California"></span><div class="qf-sourcenote">\n<span>\ue840</span><span title="The vintage year (e.g., V2022) refers to the final year of the
# ...

# %%
median = sel.css('td::text').getall()
median
# Out:
# ['\n',
#  '\n',
#  '\n',
#  '$84,097',
#  '\n',
#  '\n',
#  '\n',
#  '39,029,342',
#  '\n',
#  '\n',
#  '\n',
#  '39,538,245',
#  '\n',
#  '\n',
#  '\n',
#  '-1.3%',
#  '\n',
#  '\n',
#  '\n',
#  '39,538,223',
#  '\n',
#  '\n',
#  '\n',
#  '37,253,956',
#  '\n',
#  '\n',
#  '\n',
#  '5.5%',
#  '\n',
#  '\n',
#  '\n',
#  '21.8%',
#  '\n',
#  '\n',
#  '\n',
#  '15.8%',
#  '\n',
#  '\n',
#  '\n',
#  '49.9%',
#  '\n',
#  '\n',
#  '\n',
#  '70.7%',
#  '\n',
#  '\n',
#  '\n',
#  '6.5%',
#  '\n',
#  '\n',
#  '\n',
#  '1.7%',
#  '\n',
#  '\n',
#  '\n',
#  '16.3%',
#  '\n',
#  '\n',
#  '\n',
#  '0.5%',
#  '\n',
#  '\n',
#  '\n',
#  '4.3%',
#  '\n',
#  '\n',
#  '\n',
#  '40.3%',
#  '\n',
#  '\n',
#  '\n',
#  '34.7%',
#  '\n',
#  '\n',
#  '\n',
#  '1,467,026',
#  '\n',
#  '\n',
#  '\n',
#  '26.5%',
#  '\n',
#  '\n',
#  '\n',
#  '14,627,460',
#  '\n',
#  '\n',
#  '\n',
#  '55.5%',
#  '\n',
#  '\n',
#  '\n',
#  '$573,200',
#  '\n',
#  '\n',
#  '\n',
#  '$2,548',
#  '\n',
#  '\n',
#  '\n',
# ...

# %%
caurl='https://www.census.gov/quickfacts/fact/table/WI/INC110221#INC110221'
response = requests.get(caurl)
sel= Selector(text=response.text)
median = sel.css('td::text').getall()[3]
median
# Out:
# '$67,080'
