# %%
import pandas as pd

url = "https://www.electoralcalculus.co.uk/prediction_main.html"

tables = pd.read_html(url)
df = tables[0]

print(df)
df
# Out:
#        Party 2019 Votes  2019 Seats Pred Votes  Low Seats  Pred Seats  \
# 0        CON      44.7%         376      24.7%       44.0         126
# 1        LAB      33.0%         197      44.2%      330.0         453
# 2        LIB      11.8%           8       9.8%       13.0          31
# 3     Reform       2.1%           0      10.4%        0.0           0
# 4      Green       2.8%           1       6.4%        0.0           2
# 5        SNP       4.0%          48       3.4%        6.0          18
# 6     PlaidC       0.5%           2       0.8%        1.0           2
# 7      Other       1.1%           0       0.4%        0.0           0
# 8        DUP        NaN           8        NaN        NaN           8
# 9         SF        NaN           7        NaN        NaN           7
# 10      SDLP        NaN           2        NaN        NaN           2
# 11  Alliance        NaN           1        NaN        NaN           1
#
#     High Seats
# 0        244.0
# 1        540.0
# 2         55.0
# 3          9.0
# 4          3.0
# 5         39.0
# 6          4.0
# 7          1.0
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
#        Party 2019 Votes  2019 Seats Pred Votes  Low Seats  Pred Seats  \
# 0        CON      44.7%         376      24.7%       44.0         126
# 1        LAB      33.0%         197      44.2%      330.0         453
# 2        LIB      11.8%           8       9.8%       13.0          31
# 3     Reform       2.1%           0      10.4%        0.0           0
# 4      Green       2.8%           1       6.4%        0.0           2
# 5        SNP       4.0%          48       3.4%        6.0          18
# 6     PlaidC       0.5%           2       0.8%        1.0           2
# 7      Other       1.1%           0       0.4%        0.0           0
# 8        DUP        NaN           8        NaN        NaN           8
# 9         SF        NaN           7        NaN        NaN           7
# 10      SDLP        NaN           2        NaN        NaN           2
# 11  Alliance        NaN           1        NaN        NaN           1
#
#     High Seats
# 0        244.0
# 1        540.0
# 2         55.0
# 3          9.0
# 4          3.0
# 5         39.0
# 6          4.0
# 7          1.0
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN

# %%
df.to_csv('electoral_calculus_data.csv', index=False)
