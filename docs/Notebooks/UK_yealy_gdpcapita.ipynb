# %% [markdown]
# # UK Yearly GDP Per Capita Data
# This data summarises the GDP per capita in the UK for each year. GDP per capita was favoured insted of GDP as a better comparison between variables would be seen with GDP per capita.

# %%
import requests
#Importing commands

# %%
url = "https://www.macrotrends.net/countries/GBR/united-kingdom/gdp-per-capita"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
#Defining the user agent to avoid the blockage on the website
response = requests.get(url, headers=headers)

if response.status_code == 200:
    dfs = pd.read_html(response.text)
    
    if dfs:
        df = dfs[1]
        #Scraping the variables from the second table in the link
        print(df)
    else:
        print("No tables found")
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

df = df.rename(columns={'GDP Per Capita (US $)': 'UK GDP Per Capita (US $)'})
#Saving the data to a new dataframe to only have two of the selected columns
df
# Out:
#    U.K. GDP Per Capita - Historical Data                        \
#                                     Year GDP Per Capita (US $)
# 0                                   2022               $45,850
# 1                                   2021               $46,586
# 2                                   2020               $40,318
# 3                                   2019               $42,747
# 4                                   2018               $43,306
# ..                                   ...                   ...
# 58                                  1964                $1,748
# 59                                  1963                $1,613
# 60                                  1962                $1,526
# 61                                  1961                $1,472
# 62                                  1960                $1,398
#
#
#    Annual Growth Rate (%)
# 0                  -1.58%
# 1                  15.54%
# 2                  -5.68%
# 3                  -1.29%
# ...

# %%
df.to_csv('uk_yearly_gdpcapita', index=False)
#Saving the data to a CSV file
