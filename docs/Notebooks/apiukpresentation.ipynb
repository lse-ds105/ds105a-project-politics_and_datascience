# %%
import requests

url = "https://api.beta.ons.gov.uk/v1/datasets"

# Sending a GET request
response = requests.get(url)

# Checking the response status
if response.status_code == 200:
    # Successful request
    print("Request successful!")
    data = response.json()  # Assuming the response is in JSON format
    print(data)
else:
    # Unsuccessful request
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Request successful!
# {'@context': 'https://cdn.ons.gov.uk/assets/json-ld/context.json', 'count': 20, 'items': [{'contacts': [{'email': 'qualityoflife@ons.gov.uk', 'name': 'Will Shufflebottom, Owain Birrell, Pavan Bains and Geeta Kerai', 'telephone': '+44 300 0671543'}], 'description': 'Seasonally and non seasonally-adjusted quarterly estimates of life satisfaction, feeling that the things done in life are worthwhile, happiness and anxiety in the UK.', 'id': 'wellbeing-quarterly', 'keywords': ['well-being'], 'links': {'editions': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/wellbeing-quarterly/editions'}, 'latest_version': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/wellbeing-quarterly/editions/time-series/versions/9', 'id': '9'}, 'self': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/wellbeing-quarterly'}, 'taxonomy': {'href': 'https://api.beta.ons.gov.uk/v1/peoplepopulationandcommunity/wellbeing'}}, 'methodologies': [{'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/wellbeing/methodologies/personalwellbeingquarterlyestimatestechnicalreport', 'title': 'Personal well-being quarterly estimates technical report'}], 'national_statistic': False, 'next_release': 'TBC', 'qmi': {'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/wellbeing/methodologies/personalwellbeingintheukqmi'}, 'related_datasets': [{'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/wellbeing/datasets/ukmeasuresofnationalwellbeing', 'title': 'Personal well-being in the UK'}], 'release_frequency': 'Quarterly', 'state': 'published', 'title': 'Quarterly personal well-being estimates', 'unit_of_measure': 'Percentage'}, {'contacts': [{'email': 'QualityOfLife@ons.gov.uk', 'name': 'Rachel Mullis, Joe Shepherd and Geeta Kerai', 'telephone': '+44 3000 671 543'}], 'description': 'Estimates of life satisfaction, feeling that the things done in life are worthwhile, happiness and anxiety at the UK, country, regional, county, local and unitary authority level.', 'id': 'wellbeing-local-authority', 'keywords': ['well-being'], 'links': {'editions': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/wellbeing-local-authority/editions'}, 'latest_version': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/wellbeing-local-authority/editions/time-series/versions/4', 'id': '4'}, 'self': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/wellbeing-local-authority'}, 'taxonomy': {'href': 'https://api.beta.ons.gov.uk/v1/peoplepopulationandcommunity/wellbeing'}}, 'national_statistic': True, 'next_release': 'TBC', 'qmi': {'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/wellbeing/methodologies/personalwellbeingintheukqmi'}, 'related_datasets': [{'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/wellbeing/bulletins/measuringnationalwellbeing/april2022tomarch2023', 'title': 'Personal well-being in the UK: April 2022 to March 2023'}], 'release_frequency': 'Annual', 'state': 'published', 'title': 'Personal well-being estimates by local authority', 'unit_of_measure': 'Percentage'}, {'contacts': [{'email': 'health.data@ons.gov.uk', 'name': 'Sarah Caul', 'telephone': '+44 1329 444110'}], 'description': 'Provisional counts of the number of deaths registered in England and Wales, by region, in the latest weeks for which data are available.', 'id': 'weekly-deaths-region', 'keywords': ['Deaths', 'weekly deaths'], 'links': {'editions': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/weekly-deaths-region/editions'}, 'latest_version': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/weekly-deaths-region/editions/time-series/versions/3', 'id': '3'}, 'self': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/weekly-deaths-region'}, 'taxonomy': {'href': 'https://api.beta.ons.gov.uk/v1/peoplepopulationandcommunity/birthsdeathsandmarriages/deaths'}}, 'national_statistic': True, 'next_release': '7 February 2024', 'qmi': {'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/birthsdeathsandmarriages/deaths/methodologies/mortalitystatisticsinenglandandwalesq ...

# %%
import requests

url = 'https://api.beta.ons.gov.uk/v1/datasets/sexual-orientation-by-region'
# Sending a GET request
response = requests.get(url)

# Checking the response status
if response.status_code == 200:
    # Successful request
    print("Request successful!")
    data = response.json()  # Assuming the response is in JSON format
    print(data)
else:
    # Unsuccessful request
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Request successful!
# {'@context': 'https://cdn.ons.gov.uk/assets/json-ld/context.json', 'contacts': [{'email': 'pop.info@ons.gov.uk', 'name': 'Amanda Sharfman and Pamela Cobb', 'telephone': '+44 (0)1329 444661'}], 'description': 'Sexual orientation in the UK from 2012 to 2020 by region.\n\nData source: Annual Population Survey, ONS\n', 'id': 'sexual-orientation-by-region', 'keywords': ['gay', 'lesbian,bisexual,straight,LGB'], 'links': {'editions': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/sexual-orientation-by-region/editions'}, 'latest_version': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/sexual-orientation-by-region/editions/time-series/versions/3', 'id': '3'}, 'self': {'href': 'https://api.beta.ons.gov.uk/v1/datasets/sexual-orientation-by-region'}, 'taxonomy': {'href': 'https://api.beta.ons.gov.uk/v1/peoplepopulationandcommunity/culturalidentity/sexuality'}}, 'national_statistic': False, 'next_release': 'To be announced', 'publications': [{'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/culturalidentity/sexuality/bulletins/sexualidentityuk/2020', 'title': 'Sexual orientation, UK'}], 'qmi': {'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/culturalidentity/sexuality/methodologies/sexualidentityukqmi'}, 'related_datasets': [{'href': 'https://www.ons.gov.uk/peoplepopulationandcommunity/culturalidentity/sexuality/datasets/sexualidentityuk', 'title': 'Sexual orientation, UK, dataset'}], 'release_frequency': 'Annual', 'state': 'published', 'title': 'Sexual orientation by English regions and UK countries', 'type': 'filterable', 'unit_of_measure': 'Number of people (thousands) and percentage'}

# %%
import requests

url = 'https://test-api.service.hmrc.gov.uk'
# Sending a GET request
response = requests.get(url)

# Checking the response status
if response.status_code == 200:
    # Successful request
    print("Request successful!")
    data = response.json()  # Assuming the response is in JSON format
    print(data)
else:
    # Unsuccessful request
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# Error: 404
# {"code": "MATCHING_RESOURCE_NOT_FOUND", "message": "A resource with the name in the request can not be found in the API"}

# %% [markdown]
# # notes for presentation
# 1. alot of apis bring you to exel files where data is stored... easer to just go straight ot exel? ONS API is good but just gives you links to edexel csv files with data in
# 2. alot over governemnt data is securely protected
# 3. data we need has most likely been collected in past and stored in data frame by someone else... real task is the presentation
#
#
# # crime rates over time using below api
#
# #https://data.police.uk/docs/method/crime-street/

# %% [markdown]
# ### newcastle central station

# %%
import requests

months=['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

crimerates2021newcastle=[]

for month in months:
    url = 'https://data.police.uk/api/crimes-street/all-crime?lat=54.9691552&lng=-1.6188458&date=2021-'+month+''
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json() 
        crimerates2021newcastle.append(len(data))
    else:
        print(f"Error: {response.status_code}")
        print(response.text)


print(crimerates2021newcastle)
# Out:
# [995, 889, 1201, 1141, 1343, 1458, 1515, 1705, 1463, 1715, 1692, 1544]

# %% [markdown]
#  ### london kings cross

# %%
# finding change of crime rates overtime in london
import requests

months=['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

crimerates2021london=[]

for month in months:
    url = 'https://data.police.uk/api/crimes-street/all-crime?lat=51.5307106&lng=-0.1274346&date=2021-'+month+''
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()  # Assuming the response is in JSON format
        crimerates2021london.append(len(data))
    else:
        print(f"Error: {response.status_code}")
        print(response.text)

print(crimerates2021london)
# Out:
# [1505, 1553, 1896, 1938, 2326, 2519, 2453, 2330, 2261, 2594, 2550, 2301]

# %% [markdown]
# # manchester piccadilly station

# %%
months=['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

crimerates2021manchester=[]

for month in months:
    url = 'https://data.police.uk/api/crimes-street/all-crime?lat=53.4810422&lng=-2.2440995&date=2021-'+month+''
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()  # Assuming the response is in JSON format
        crimerates2021manchester.append(len(data))
    else:
        print(f"Error: {response.status_code}")
        print(response.text)


print(crimerates2021manchester)
# Out:
# [36, 10, 13, 17, 8, 38, 71, 61, 40, 52, 54, 40]

# %% [markdown]
# # portsmouth fratton station

# %%
months=['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

crimerates2021portsmouth=[]

for month in months:
    url = 'https://data.police.uk/api/crimes-street/all-crime?lat=50.7964591&lng=-1.0764905&date=2021-'+month+''
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()  # Assuming the response is in JSON format
        crimerates2021portsmouth.append(len(data))
    else:
        print(f"Error: {response.status_code}")
        print(response.text)


print(crimerates2021portsmouth)
# Out:
# [1093, 1003, 1314, 1335, 1422, 1439, 1355, 1421, 1447, 1496, 1599, 1389]

# %%
import requests
import pandas as pd

crimerates2021 = pd.DataFrame({
    'Month': months,
    'London': crimerates2021london,
    'Manchester': crimerates2021manchester,
    'Newcastle': crimerates2021newcastle,
    'Portsmouth': crimerates2021portsmouth
})


crimerates2021.to_csv('crimerates2021.csv', index=False)

# %%
import requests
# %pip install streamlit
import pandas as pd
import streamlit as st

# %pip install altair pandas vega_datasets
# %pip install -U altair_viewer
# %pip install streamlit
import altair as alt
# Out:
# Requirement already satisfied: streamlit in /Users/maddonk/anaconda3/lib/python3.11/site-packages (1.30.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (2.1.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (4.7.1)
# Requirement already satisfied: tzlocal<6,>=1.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: altair in /Users/maddonk/anaconda3/lib/python3.11/site-packages (5.2.0)
# Requirement already satisfied: pandas in /Users/maddonk/anaconda3/lib/python3.11/site-packages (2.1.2)
# Requirement already satisfied: vega_datasets in /Users/maddonk/anaconda3/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: jinja2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair) (4.17.3)
# Requirement already satisfied: numpy in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair) (1.24.3)
# Requirement already satisfied: packaging in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair) (23.0)
# Requirement already satisfied: toolz in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair) (0.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair) (0.18.0)
# Requirement already satisfied: six>=1.5 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jinja2->altair) (2.1.1)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: altair_viewer in /Users/maddonk/anaconda3/lib/python3.11/site-packages (0.4.0)
# Requirement already satisfied: altair in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair_viewer) (5.2.0)
# Requirement already satisfied: altair-data-server>=0.4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair_viewer) (0.4.1)
# Requirement already satisfied: portpicker in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair-data-server>=0.4.0->altair_viewer) (1.6.0)
# Requirement already satisfied: tornado in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair-data-server>=0.4.0->altair_viewer) (6.3.2)
# Requirement already satisfied: jinja2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair->altair_viewer) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair->altair_viewer) (4.17.3)
# Requirement already satisfied: numpy in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair->altair_viewer) (1.24.3)
# Requirement already satisfied: packaging in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair->altair_viewer) (23.0)
# Requirement already satisfied: pandas>=0.25 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair->altair_viewer) (2.1.2)
# Requirement already satisfied: toolz in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair->altair_viewer) (0.12.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair->altair_viewer) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair->altair_viewer) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->altair->altair_viewer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->altair->altair_viewer) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas>=0.25->altair->altair_viewer) (2023.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jinja2->altair->altair_viewer) (2.1.1)
# Requirement already satisfied: psutil in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from portpicker->altair-data-server>=0.4.0->altair_viewer) (5.9.0)
# Requirement already satisfied: six>=1.5 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.25->altair->altair_viewer) (1.16.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: streamlit in /Users/maddonk/anaconda3/lib/python3.11/site-packages (1.30.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<8,>=1.4 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (1.24.3)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (2.1.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (4.7.1)
# Requirement already satisfied: tzlocal<6,>=1.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: jinja2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from importlib-metadata<8,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.11.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/maddonk/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt


Crimegraph = alt.Chart(crimerates2021).mark_line().encode(
    x=alt.X('Month:O', title='Month'),  
    color=alt.Color('city:N', title='City'), 
    y=alt.Y('crime_rate:Q', title='Crime Rates'),
    tooltip=['Month:O', 'city:N', 'crime_rate:Q'] 
).properties(
    width=500, 
    height=300,
    title='Crime Rates in Cities (2021)'
).transform_fold(  
    fold=['London', 'Manchester', 'Newcastle', 'Portsmouth' ],
    as_=['city', 'crime_rate']

)

Crimegraph
# Out:
# alt.Chart(...)

# %%
# manchester data not collected? problems with effiecency of data collection in different cities 
#perhaps manchester had stronger covid lockdowsn, in

# %%
import requests

url = 'https://data.police.uk/api/crimes-street/all-crime?lat=54.991677&lng=-1.603831&date=2022-01'
response = requests.get(url)
   
data = response.json()

data
# Out:
# [{'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991480',
#    'street': {'id': 1026388, 'name': "On or near Queen's Terrace"},
#    'longitude': '-1.601369'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918439,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.985760',
#    'street': {'id': 1026231, 'name': 'On or near Northumberland Gardens'},
#    'longitude': '-1.591799'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917781,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.985393',
#    'street': {'id': 1026377, 'name': 'On or near Eslington Terrace'},
#    'longitude': '-1.606039'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917769,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.989927',
#    'street': {'id': 1026390, 'name': 'On or near Osborne Road'},
#    'longitude': '-1.604744'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916772,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.983096',
#    'street': {'id': 1026332, 'name': 'On or near Greystoke Avenue'},
#    'longitude': '-1.593186'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917747,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '55.002041',
#    'street': {'id': 1027577, 'name': 'On or near Craghall Dene'},
#    'longitude': '-1.604922'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917693,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.988131',
#    'street': {'id': 1026247, 'name': 'On or near Farquhar Street'},
#    'longitude': '-1.596932'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917638,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979779',
#    'street': {'id': 1024647, 'name': 'On or near Stratford Road'},
#    'longitude': '-1.590391'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917323,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978735',
#    'street': {'id': 1024376, 'name': 'On or near Wesley Street'},
#    'longitude': '-1.600683'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917612,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.988601',
#    'street': {'id': 1026373, 'name': 'On or near Holly Avenue West'},
#    'longitude': '-1.605867'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917642,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.987358',
#    'street': {'id': 1026404, 'name': 'On or near Hospital'},
#    'longitude': '-1.604910'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917576,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.989927',
#    'street': {'id': 1026390, 'name': 'On or near Osborne Road'},
#    'longitude': '-1.604744'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916450,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.985393',
#    'street': {'id': 1026377, 'name': 'On or near Eslington Terrace'},
#    'longitude': '-1.606039'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917496,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995679',
#    'street': {'id': 1027768, 'name': 'On or near Newton Place'},
#    'longitude': '-1.586040'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917332,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.992778',
#    'street': {'id': 1026383, 'name': 'On or near Sycamore Close'},
#    'longitude': '-1.602528'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917475,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.986933',
#    'street': {'id': 1026248, 'name': 'On or near Deuchar Street'},
#    'longitude': '-1.596038'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917474,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.985133',
#    'street': {'id': 1026402, 'name': 'On or near Akenside Terrace'},
#    'longitude': '-1.600744'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917394,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '55.005065',
#    'street': {'id': 1027570, 'name': 'On or near Mill Rise'},
#    'longitude': '-1.603407'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917381,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.986688',
#    'street': {'id': 1026226, 'name': 'On or near Rosebery Crescent'},
#    'longitude': '-1.592728'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917340,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978019',
#    'street': {'id': 1024379, 'name': 'On or near Shield Street'},
#    'longitude': '-1.601580'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915790,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981194',
#    'street': {'id': 1024672, 'name': 'On or near Chelmsford Grove'},
#    'longitude': '-1.594205'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916268,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.982675',
#    'street': {'id': 1026408, 'name': 'On or near Osborne Terrace'},
#    'longitude': '-1.604581'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915976,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.992331',
#    'street': {'id': 1026296, 'name': 'On or near A188'},
#    'longitude': '-1.579245'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917557,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.997527',
#    'street': {'id': 1027770, 'name': 'On or near Lynmouth Place'},
#    'longitude': '-1.582473'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918238,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.998754',
#    'street': {'id': 1027728, 'name': 'On or near Boundary Gardens'},
#    'longitude': '-1.591886'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916589,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979779',
#    'street': {'id': 1024647, 'name': 'On or near Stratford Road'},
#    'longitude': '-1.590391'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915780,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980237',
#    'street': {'id': 1024502, 'name': 'On or near A167(m)'},
#    'longitude': '-1.612105'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915855,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.988102',
#    'street': {'id': 1026221, 'name': 'On or near Shortridge Terrace'},
#    'longitude': '-1.596355'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915684,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.983789',
#    'street': {'id': 1026417, 'name': 'On or near Osborne Road'},
#    'longitude': '-1.604570'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915979,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994773',
#    'street': {'id': 1027775, 'name': 'On or near Acton Place'},
#    'longitude': '-1.581283'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916980,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981831',
#    'street': {'id': 1026331, 'name': 'On or near Helmsley Road'},
#    'longitude': '-1.596574'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916961,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995626',
#    'street': {'id': 1027663, 'name': 'On or near North Jesmond Avenue'},
#    'longitude': '-1.605345'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918747,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995889',
#    'street': {'id': 1027766, 'name': 'On or near Supermarket'},
#    'longitude': '-1.586992'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918688,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990568',
#    'street': {'id': 1026342, 'name': 'On or near Valley View'},
#    'longitude': '-1.597361'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918659,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991293',
#    'street': {'id': 1026267, 'name': 'On or near Stephenson Road'},
#    'longitude': '-1.583241'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918617,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.993206',
#    'street': {'id': 1026356, 'name': 'On or near Brentwood Avenue'},
#    'longitude': '-1.609932'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918557,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994135',
#    'street': {'id': 1026376, 'name': 'On or near Glenthorn Road'},
#    'longitude': '-1.608110'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918552,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.985360',
#    'street': {'id': 1026354, 'name': 'On or near Clayton Park Square'},
#    'longitude': '-1.609555'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916943,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991786',
#    'street': {'id': 1026365, 'name': "On or near St George's Mews"},
#    'longitude': '-1.607227'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918550,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990043',
#    'street': {'id': 1026389, 'name': "On or near Queen's Road"},
#    'longitude': '-1.601602'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918537,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.989581',
#    'street': {'id': 1026271, 'name': 'On or near Sefton Avenue'},
#    'longitude': '-1.579227'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916443,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990532',
#    'street': {'id': 1026400, 'name': 'On or near Devonshire Place'},
#    'longitude': '-1.600081'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918536,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994135',
#    'street': {'id': 1026376, 'name': 'On or near Glenthorn Road'},
#    'longitude': '-1.608110'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916618,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980789',
#    'street': {'id': 1024396, 'name': 'On or near Grantham Road'},
#    'longitude': '-1.599397'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918520,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.989375',
#    'street': {'id': 1026250, 'name': 'On or near Collingwood Terrace'},
#    'longitude': '-1.595404'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918501,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991786',
#    'street': {'id': 1026365, 'name': "On or near St George's Mews"},
#    'longitude': '-1.607227'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918462,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990649',
#    'street': {'id': 1026395, 'name': 'On or near Grosvenor Place'},
#    'longitude': '-1.602893'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918411,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991611',
#    'street': {'id': 1026352, 'name': 'On or near Forsyth Road'},
#    'longitude': '-1.611339'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918315,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990532',
#    'street': {'id': 1026400, 'name': 'On or near Devonshire Place'},
#    'longitude': '-1.600081'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918214,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.989638',
#    'street': {'id': 1026392, 'name': 'On or near Manor House Road'},
#    'longitude': '-1.598777'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916909,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.996297',
#    'street': {'id': 1027769, 'name': 'On or near Lynnholm Close'},
#    'longitude': '-1.585331'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918169,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.998151',
#    'street': {'id': 1027611, 'name': 'On or near Jesmond Dene Road'},
#    'longitude': '-1.610791'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915661,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.993521',
#    'street': {'id': 1026384, 'name': 'On or near Sanderson Road'},
#    'longitude': '-1.604600'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918151,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.993086',
#    'street': {'id': 1026364, 'name': "On or near St George's Terrace"},
#    'longitude': '-1.606198'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98916627,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990532',
#    'street': {'id': 1026400, 'name': 'On or near Devonshire Place'},
#    'longitude': '-1.600081'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918107,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.989638',
#    'street': {'id': 1026392, 'name': 'On or near Manor House Road'},
#    'longitude': '-1.598777'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918101,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981789',
#    'street': {'id': 1026301, 'name': 'On or near Parking Area'},
#    'longitude': '-1.586730'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918040,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995511',
#    'street': {'id': 1027774, 'name': 'On or near Craster Terrace'},
#    'longitude': '-1.581666'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918032,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991480',
#    'street': {'id': 1026388, 'name': "On or near Queen's Terrace"},
#    'longitude': '-1.601369'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918012,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990564',
#    'street': {'id': 1026367, 'name': 'On or near Norham Place'},
#    'longitude': '-1.607114'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915680,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.988946',
#    'street': {'id': 1015441, 'name': 'On or near Ivymount Road'},
#    'longitude': '-1.585313'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917841,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994918',
#    'street': {'id': 1027666, 'name': 'On or near Lonsdale Terrace'},
#    'longitude': '-1.608603'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917782,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979220',
#    'street': {'id': 1024399, 'name': 'On or near Gladstone Place'},
#    'longitude': '-1.603271'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98915897,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980407',
#    'street': {'id': 1024394, 'name': 'On or near Harrison Place'},
#    'longitude': '-1.603557'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917667,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.987358',
#    'street': {'id': 1026404, 'name': 'On or near Hospital'},
#    'longitude': '-1.604910'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917668,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995511',
#    'street': {'id': 1027774, 'name': 'On or near Craster Terrace'},
#    'longitude': '-1.581666'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98917955,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.977575',
#    'street': {'id': 1024397, 'name': 'On or near Gosforth Street'},
#    'longitude': '-1.600522'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918177,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995532',
#    'street': {'id': 1027655, 'name': 'On or near Myrtle Grove'},
#    'longitude': '-1.609504'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918195,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'anti-social-behaviour',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990899',
#    'street': {'id': 1026252, 'name': 'On or near Cavendish Road'},
#    'longitude': '-1.596764'},
#   'context': '',
#   'outcome_status': None,
#   'persistent_id': '',
#   'id': 98918215,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.982313',
#    'street': {'id': 1026423, 'name': 'On or near Park Terrace'},
#    'longitude': '-1.615007'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'c84ff610e9e6e324665ffe7c92bff67050ac5de4c3b844c779071255e2dddd4e',
#   'id': 98909061,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981662',
#    'street': {'id': 1026336, 'name': 'On or near Amble Grove'},
#    'longitude': '-1.594544'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '80837ee8708c0a312ca4f2c3f9a5c6c30507d0fc9c5628057c833b190b1b4b09',
#   'id': 98902303,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979384',
#    'street': {'id': 1024422, 'name': 'On or near Sandyford Road'},
#    'longitude': '-1.609441'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'a7f278e1d155a35f7c16f151342b595a39bef82ba1af59015c9ceaeb6ffbd007',
#   'id': 98901703,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980824',
#    'street': {'id': 1024492, 'name': 'On or near Jesmond Road West'},
#    'longitude': '-1.610177'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'e7432356ac07485f868765c3b1b5becab13ce237e3a86ee579684cb88cec594d',
#   'id': 98901695,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980407',
#    'street': {'id': 1024394, 'name': 'On or near Harrison Place'},
#    'longitude': '-1.603557'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '29e162750c2836a6123da3eda61af5daa71ab86f50670df6cf8fcb84c70a9d39',
#   'id': 98915110,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981518',
#    'street': {'id': 1026425, 'name': 'On or near Claremont Road'},
#    'longitude': '-1.616515'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '35aa19f85f534f3820fd9509d473c8b5e90c1a29077a96e4acb2f2d835b60e2a',
#   'id': 98914296,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980407',
#    'street': {'id': 1024394, 'name': 'On or near Harrison Place'},
#    'longitude': '-1.603557'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '1984d8739ce26691c13bae3b3d3083f65d697313a63b3359f54f697e4f7f76d7',
#   'id': 98906480,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.982447',
#    'street': {'id': 1026330, 'name': 'On or near Kelvin Grove'},
#    'longitude': '-1.598068'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '5b0506407da0ca115432bab8a6761d0040b35ec6c2a4708c75cdcedf07f54134',
#   'id': 98906383,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980824',
#    'street': {'id': 1024492, 'name': 'On or near Jesmond Road West'},
#    'longitude': '-1.610177'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '1fe69fca7051d97b0b4acfbe13f0e89237c73634c9c8e8e433cad56475f4e5f5',
#   'id': 98905765,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981518',
#    'street': {'id': 1026425, 'name': 'On or near Claremont Road'},
#    'longitude': '-1.616515'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'f731041cf4b209a1df7f56b3405ceabf0c5bed26ab4d5022a76550390558d9a3',
#   'id': 98905591,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '55.004163',
#    'street': {'id': 1027586, 'name': 'On or near Stoneyhurst Road'},
#    'longitude': '-1.608013'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'e85de2eaededbecd5c54fea3d2c55c936b00608e86a912c78631ab157ac5ce2b',
#   'id': 98898594,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980824',
#    'street': {'id': 1024492, 'name': 'On or near Jesmond Road West'},
#    'longitude': '-1.610177'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '21769efcdbf0aee75a48888098531bc97cd8cff4a31692dc044f3fbc8cdd3375',
#   'id': 98897215,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981518',
#    'street': {'id': 1026425, 'name': 'On or near Claremont Road'},
#    'longitude': '-1.616515'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': 'ff28f76dcede526aa862bd3f9ffe374d91179e9fef2c1b9d1f71e52ab74bc434',
#   'id': 98898939,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991480',
#    'street': {'id': 1026388, 'name': "On or near Queen's Terrace"},
#    'longitude': '-1.601369'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '7c4d946e0d51f462d4a3601c3a0cc8a0fa33265855e2f22570b6c46d3ba39fca',
#   'id': 98896876,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.987323',
#    'street': {'id': 1026237, 'name': 'On or near Jesmond Road'},
#    'longitude': '-1.594237'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '79b37ff6844f1ca6287e52a214eb95feee64080918e71ee49955313b4e2178cc',
#   'id': 98900383,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.986367',
#    'street': {'id': 1026355, 'name': 'On or near Burdon Terrace'},
#    'longitude': '-1.609733'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '78d2de153bc655331686b56e0c17b13627a68238b1f8674aaf8661e023375dd3',
#   'id': 98899705,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980824',
#    'street': {'id': 1024492, 'name': 'On or near Jesmond Road West'},
#    'longitude': '-1.610177'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': 'ea75e023c91c7998f1f57d7cc0a44eebea8fe49a85439a3e36dcd681a0bf32d1',
#   'id': 98913448,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981518',
#    'street': {'id': 1026425, 'name': 'On or near Claremont Road'},
#    'longitude': '-1.616515'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '02c0d840401260c4022e8093ae0c44e4616b053d8d6be8127ed9c57b3779b34b',
#   'id': 98905409,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979384',
#    'street': {'id': 1024422, 'name': 'On or near Sandyford Road'},
#    'longitude': '-1.609441'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '2652c93d74014a5b4411bbd6fac347be1dae2b930f8ba4ac7b5cd6fd5a58d1de',
#   'id': 98914765,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981518',
#    'street': {'id': 1026425, 'name': 'On or near Claremont Road'},
#    'longitude': '-1.616515'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-04'},
#   'persistent_id': 'c920c5822dbe72a6aac5f36c6e09a45510b38be8d59e1cc0b52ecf9fbe15600d',
#   'id': 98901884,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978246',
#    'street': {'id': 1024387, 'name': 'On or near Napier Street'},
#    'longitude': '-1.602375'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-03'},
#   'persistent_id': '68fa307d994e1652de22cb4ae13afe185e1234c7303d481ebd217d5d46ec5044',
#   'id': 98905869,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978246',
#    'street': {'id': 1024387, 'name': 'On or near Napier Street'},
#    'longitude': '-1.602375'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-03'},
#   'persistent_id': '1f4bc83d7d09d278743bbc24fcf48d4fa17c1447d6d020540a5dc45e55d069ac',
#   'id': 98905885,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994790',
#    'street': {'id': 1027658, 'name': 'On or near Lyndhurst Avenue'},
#    'longitude': '-1.610574'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '3f755691bd2c2ffbfc4c6ace35df5f8fe51b8ce58c7bbfeb2321a3a7bed03e45',
#   'id': 98913602,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978246',
#    'street': {'id': 1024387, 'name': 'On or near Napier Street'},
#    'longitude': '-1.602375'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'edbffb37a48a5ef6eba965922eeb15c6f59b9a82e194a6446a7ce4699aca5874',
#   'id': 98906537,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'bicycle-theft',
#   'location_type': 'Force',
#   'location': {'latitude': '54.980824',
#    'street': {'id': 1024492, 'name': 'On or near Jesmond Road West'},
#    'longitude': '-1.610177'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'fd3af487368cfb1eaf6d6818a28bb9d67c65eaa6e987227781df2393330e8d4e',
#   'id': 98903747,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994790',
#    'street': {'id': 1027658, 'name': 'On or near Lyndhurst Avenue'},
#    'longitude': '-1.610574'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '82bc93b54cbc00f613e4e1f83efdd225d7fcbbc056db32c0a9e959fbebe61972',
#   'id': 98902655,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.986570',
#    'street': {'id': 1026234, 'name': 'On or near Lansdowne Gardens'},
#    'longitude': '-1.589478'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '64f37113497442ec0ce00f61ffc2a029393a682b7a367b8f5c65fd85354a90f5',
#   'id': 98904724,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979779',
#    'street': {'id': 1024647, 'name': 'On or near Stratford Road'},
#    'longitude': '-1.590391'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'c87504a823c67baabd400b7f35c17c2a8a2e820c3358b9d026a308d82a791937',
#   'id': 98910769,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.996723',
#    'street': {'id': 1027664, 'name': 'On or near North Jesmond Avenue'},
#    'longitude': '-1.605303'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': '8341801474aa2efd7cd318343dd9edd3935f16374ab58536ce4ee8caf40fd4ff',
#   'id': 98913572,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.987358',
#    'street': {'id': 1026404, 'name': 'On or near Hospital'},
#    'longitude': '-1.604910'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'ff1986d55045d4a3bc59f483bdb3e6a3766e5ce4b3da11d40e3f5b3fbd1bf3b9',
#   'id': 98905094,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.986366',
#    'street': {'id': 1026290, 'name': 'On or near Burlington Gardens'},
#    'longitude': '-1.582323'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '6e195e075541fc79fd7a991efa93f974af1ebb542e5ffa2118c7b5dda4f56120',
#   'id': 98902835,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990568',
#    'street': {'id': 1026342, 'name': 'On or near Valley View'},
#    'longitude': '-1.597361'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2023-02'},
#   'persistent_id': 'f7d1f06bf997287e4777099998ef77f4a7f93d32f2f05f73f75844efca32f562',
#   'id': 98914896,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994790',
#    'street': {'id': 1027658, 'name': 'On or near Lyndhurst Avenue'},
#    'longitude': '-1.610574'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': 'b66515abdc9da479a789f87ebf242040f2b889f5e2a2987362b5fa3218f0c6f2',
#   'id': 98906774,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978573',
#    'street': {'id': 1024407, 'name': 'On or near Byron Street'},
#    'longitude': '-1.603262'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': 'ba1b397ca2e095f1748a382d82fde25e3d1902bfb85f016024491a6b7eb54f61',
#   'id': 98914708,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994790',
#    'street': {'id': 1027658, 'name': 'On or near Lyndhurst Avenue'},
#    'longitude': '-1.610574'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': '47e98ad04c25c3cc171c072c1d722057fc2aa92c78fce56f03dc573cb3f8f81c',
#   'id': 98906923,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.983820',
#    'street': {'id': 1026339, 'name': 'On or near Greystoke Gardens'},
#    'longitude': '-1.592116'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-05'},
#   'persistent_id': '51203b1502acd1fbab4ac78550cea419392a4705009002b9dcdf560838a3aacc',
#   'id': 98902322,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.982094',
#    'street': {'id': 1026407, 'name': 'On or near Portland Terrace'},
#    'longitude': '-1.602774'},
#   'context': '',
#   'outcome_status': {'category': 'Court result unavailable',
#    'date': '2022-07'},
#   'persistent_id': '4b5d05c5a8ba034d5aa10e56336edf908c15748b60bf22d43554ad045fe2884b',
#   'id': 98914711,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.983820',
#    'street': {'id': 1026339, 'name': 'On or near Greystoke Gardens'},
#    'longitude': '-1.592116'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-10'},
#   'persistent_id': 'dce623b3126cbd31aa3196d9bf7cbd649151a2d345caa78c13ba5ba34bd89a6a',
#   'id': 98902269,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978246',
#    'street': {'id': 1024387, 'name': 'On or near Napier Street'},
#    'longitude': '-1.602375'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': 'e03501c85b6e40f45882a5eed3391806015d474fdd4233103cfb4d27e774480c',
#   'id': 98915107,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.982169',
#    'street': {'id': 1026329, 'name': 'On or near Ouseburn Road'},
#    'longitude': '-1.590336'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '2d44791451206c25576ae700fea8e8c65d933a4aef7e23ad825e9b8473a1fa03',
#   'id': 98897022,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.993734',
#    'street': {'id': 1026253, 'name': 'On or near Castleton Grove'},
#    'longitude': '-1.598158'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'd0f9f223882c8899619447e227f2a48da6bb9ed0b2f14b78f527bc907fbf2495',
#   'id': 98912421,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'burglary',
#   'location_type': 'Force',
#   'location': {'latitude': '54.983820',
#    'street': {'id': 1026339, 'name': 'On or near Greystoke Gardens'},
#    'longitude': '-1.592116'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '693adb474e40100f87aedf04699dcd6de1ec631c1844034043629f99034600c1',
#   'id': 98914974,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981662',
#    'street': {'id': 1026336, 'name': 'On or near Amble Grove'},
#    'longitude': '-1.594544'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '1a0cdbf69cea48c8f7dcf940fa437ac8ac9d9770011a8942f85040a26935f337',
#   'id': 98896924,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978246',
#    'street': {'id': 1024387, 'name': 'On or near Napier Street'},
#    'longitude': '-1.602375'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-03'},
#   'persistent_id': 'f9b4dba2c4f02fa2e7e7890c0953816392a92d8e6998d1664a4f5ba70fc6d727',
#   'id': 98897120,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.986367',
#    'street': {'id': 1026355, 'name': 'On or near Burdon Terrace'},
#    'longitude': '-1.609733'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'e32caa1106a697a6b71a88148bf13461f20f02e1b2c73606f3eadf8ef9196026',
#   'id': 98911323,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.988394',
#    'street': {'id': 1026283, 'name': 'On or near Heaton Road'},
#    'longitude': '-1.581646'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'ab9e018add653b705cc862513095b23464578ccd68ed0a19d1e7997757680d60',
#   'id': 98913517,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991480',
#    'street': {'id': 1026388, 'name': "On or near Queen's Terrace"},
#    'longitude': '-1.601369'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'bd5131deccbf779fdcdb0b745a47805417129bd629ae36aba65dcbd9254aeaa8',
#   'id': 98913524,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995679',
#    'street': {'id': 1027768, 'name': 'On or near Newton Place'},
#    'longitude': '-1.586040'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-07'},
#   'persistent_id': 'ec966b131246c97d9bab93a8d2fd6da2e4290253456a0c1223f892a0c45e78a6',
#   'id': 98897278,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995511',
#    'street': {'id': 1027774, 'name': 'On or near Craster Terrace'},
#    'longitude': '-1.581666'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '0ab93589c5d5492de7a2050320ba015637d72abcf473c4ae521c56c5d4e3c1aa',
#   'id': 98914603,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981518',
#    'street': {'id': 1026425, 'name': 'On or near Claremont Road'},
#    'longitude': '-1.616515'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '02c3c51709eb76aa6ab640dfa393c5a85fdbd050a76c2ba8668dc6a63e96011a',
#   'id': 98900771,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995889',
#    'street': {'id': 1027766, 'name': 'On or near Supermarket'},
#    'longitude': '-1.586992'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': '0b34f7329083a586e3c99f3e8789b06e5413ba4d9adf186738e456a00790fc92',
#   'id': 98901165,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '54.997248',
#    'street': {'id': 1027557, 'name': 'On or near Westfield Grove'},
#    'longitude': '-1.626556'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-03'},
#   'persistent_id': '20abfac9ae0cc82c5f9d443f4d68bd061d6059bb716b8492d9ea25ab00f6136e',
#   'id': 98906518,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'criminal-damage-arson',
#   'location_type': 'Force',
#   'location': {'latitude': '55.004168',
#    'street': {'id': 1027674, 'name': 'On or near Castledene Court'},
#    'longitude': '-1.598648'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
# ...
#    'longitude': '-1.581646'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '2b915888b56478ee5aeebd87a25d77f5a0b95a72e1105983ddf5aeaa665a31ab',
#   'id': 98910032,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.986367',
#    'street': {'id': 1026355, 'name': 'On or near Burdon Terrace'},
#    'longitude': '-1.609733'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '3700d53ddbcb6990a51fc52022f262aacfc2ee03982f952865554c9ef7c82d86',
#   'id': 98897842,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995626',
#    'street': {'id': 1027663, 'name': 'On or near North Jesmond Avenue'},
#    'longitude': '-1.605345'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '42bda5ec499ce4abd12f633aa06aa7c5688af7dc742a9d1348027c3568b0e42c',
#   'id': 98898013,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.994167',
#    'street': {'id': 1026260,
#     'name': 'On or near Further/higher Educational Building'},
#    'longitude': '-1.587885'},
#   'context': '',
#   'outcome_status': {'category': 'Court result unavailable',
#    'date': '2022-07'},
#   'persistent_id': '7314fb30d973b146a6a045684c7d557f8b63b612f7dc0fc314e0601ff1d41ca8',
#   'id': 98906227,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.987358',
#    'street': {'id': 1026404, 'name': 'On or near Hospital'},
#    'longitude': '-1.604910'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '6befe4bdb11a77fc4e1c23ea29e61a1dca27642667db554495143f84f4f7ebd0',
#   'id': 98899102,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979877',
#    'street': {'id': 1024664, 'name': 'On or near Hotspur Street'},
#    'longitude': '-1.590078'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '4d5e84428092f0ce6b50ece2d36560b6631f4de28192b466dc6a34c57172a8dc',
#   'id': 98907899,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.987358',
#    'street': {'id': 1026404, 'name': 'On or near Hospital'},
#    'longitude': '-1.604910'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '80ff5e6b3a19ccfc85a8bcf509271709c9397e1c6bf23daa62bde06b886fe01b',
#   'id': 98900131,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '55.003573',
#    'street': {'id': 1027594, 'name': 'On or near Dene View'},
#    'longitude': '-1.606330'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '305658faaa3b7fe436639575d5f58635bd5736aa06d672d94280e0a7747b05cb',
#   'id': 98910442,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.978019',
#    'street': {'id': 1024379, 'name': 'On or near Shield Street'},
#    'longitude': '-1.601580'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-02'},
#   'persistent_id': 'ece6d105d83ed20ce750cd1d3023ddafb21f4fc4484725349cb46a3d4f2c625a',
#   'id': 98897676,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '55.003105',
#    'street': {'id': 1027601, 'name': 'On or near Balmoral Avenue'},
#    'longitude': '-1.608836'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '1a642e2caadd9785573909da06c401d91e7d7ef6822d48f516be1b1464b2f762',
#   'id': 98434348,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981518',
#    'street': {'id': 1026425, 'name': 'On or near Claremont Road'},
#    'longitude': '-1.616515'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '5ca55e824fdb253415568967cad3376471c626ababe86c4e7b5ce21c2d0e6373',
#   'id': 98905620,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981518',
#    'street': {'id': 1026425, 'name': 'On or near Claremont Road'},
#    'longitude': '-1.616515'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '1fec07c6fde742ca97b5fd10bb7cc3072b0f3adf9c9e616139ca7f0d0af631d3',
#   'id': 98897261,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '55.003212',
#    'street': {'id': 1027619, 'name': 'On or near The Grove'},
#    'longitude': '-1.614072'},
#   'context': '',
#   'outcome_status': {'category': 'Court result unavailable',
#    'date': '2022-07'},
#   'persistent_id': '764260dbcee4751ebb086824278698537c390220dce9f6bda85f92d6ee704611',
#   'id': 98897523,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995626',
#    'street': {'id': 1027663, 'name': 'On or near North Jesmond Avenue'},
#    'longitude': '-1.605345'},
#   'context': '',
#   'outcome_status': {'category': 'Offender given a caution',
#    'date': '2022-01'},
#   'persistent_id': '441a6662e7958935550edc62adac5124739c3c75b8a303458cfe4fd22c705fcc',
#   'id': 98898032,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.987358',
#    'street': {'id': 1026404, 'name': 'On or near Hospital'},
#    'longitude': '-1.604910'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'fd5b5a8d0145887d95710021a13c3f0eeeb837941b4722a2375906a99e1b414c',
#   'id': 98902371,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.984072',
#    'street': {'id': 1026337, 'name': 'On or near Park/open Space'},
#    'longitude': '-1.587066'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '73638493760805aeefc250c6e8ce8abe2805e2c16673e0433c74c10c8975bbd5',
#   'id': 98907613,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '55.005555',
#    'street': {'id': 1027582, 'name': 'On or near Audley Road'},
#    'longitude': '-1.604966'},
#   'context': '',
#   'outcome_status': {'category': 'Offender given a caution',
#    'date': '2023-06'},
#   'persistent_id': '48f3e89958b6bf73851e20892a0dacf663aa9902e4ca7e952fe5aed4a5a3ae70',
#   'id': 98901525,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.997680',
#    'street': {'id': 1027764, 'name': 'On or near Beanley Place'},
#    'longitude': '-1.587849'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'ab528664314f86f7139f36be12adb9331fcf2a72a78fc980575809f348ab4149',
#   'id': 98907893,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.977774',
#    'street': {'id': 1024431, 'name': 'On or near College Lane'},
#    'longitude': '-1.609051'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '07a89cb2ad6f6dfd51ca3ff180b46cc7dbcbf6c67598c1deab61407c1350175a',
#   'id': 98909347,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990568',
#    'street': {'id': 1026342, 'name': 'On or near Valley View'},
#    'longitude': '-1.597361'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '594d663c7d68b84894feefb23c1bb9b2f43d0e5679ea05189191f736ea892b60',
#   'id': 98914092,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.997175',
#    'street': {'id': 1027672, 'name': 'On or near Bemersyde Drive'},
#    'longitude': '-1.603407'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'f94c4ebfb6a55e6e33f4be249544a76512390a46dabdfbbcafcf6834033bb9a7',
#   'id': 98911328,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981222',
#    'street': {'id': 1024433, 'name': 'On or near Archbold Terrace'},
#    'longitude': '-1.605549'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'c48fb9075a35f36969d32673dcdf3d3277c60db508adb9d0f8689527a7020158',
#   'id': 98901017,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979877',
#    'street': {'id': 1024664, 'name': 'On or near Hotspur Street'},
#    'longitude': '-1.590078'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '6541571812e9c479c3464ed2ecbc289e08289e003aa892f14df200f5287d7c87',
#   'id': 98901666,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '55.004168',
#    'street': {'id': 1027674, 'name': 'On or near Castledene Court'},
#    'longitude': '-1.598648'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'fe10c11410af6e0d283eeef62eaa15255be26d47fde4bf782f6830692a9ffa97',
#   'id': 98906658,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.990568',
#    'street': {'id': 1026342, 'name': 'On or near Valley View'},
#    'longitude': '-1.597361'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'b109c188593057b2b037792505fb4c7db2aa1e8dcd76949f558205c52cd30743',
#   'id': 98896930,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995511',
#    'street': {'id': 1027774, 'name': 'On or near Craster Terrace'},
#    'longitude': '-1.581666'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'fe878b89c96d9ebe7239dbe403ec748bdcd7737aaf0fb3187a800bd98df49bf9',
#   'id': 98914371,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979384',
#    'street': {'id': 1024422, 'name': 'On or near Sandyford Road'},
#    'longitude': '-1.609441'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'a0931b793d925de8e998e69ca7cf5efa87cfbb76b33213ab0dc3bbb1537a8595',
#   'id': 98912805,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.995889',
#    'street': {'id': 1027766, 'name': 'On or near Supermarket'},
#    'longitude': '-1.586992'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'ca2dbc50aec5428ff44b4494b3ded5d8a90dec139f6161451edb69e763b344cc',
#   'id': 98911456,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981916',
#    'street': {'id': 1026406, 'name': 'On or near Sandyford Road'},
#    'longitude': '-1.600635'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '3f876217b590a79bd9707683960e73d205da27d847122c60b719c0adc8fc8d02',
#   'id': 98910315,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.987674',
#    'street': {'id': 1026391, 'name': 'On or near Osborne Avenue'},
#    'longitude': '-1.599859'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': 'aa8087c773fab58c5dc00266a61afc63f69cb5f3888956c6a58154e490278af0',
#   'id': 98909549,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.991786',
#    'street': {'id': 1026365, 'name': "On or near St George's Mews"},
#    'longitude': '-1.607227'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': '657da778fbe16494494176a724908190d3242d4bb5a5d9f940541dd736eb9e24',
#   'id': 98908774,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'violent-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.981614',
#    'street': {'id': 1026427,
#     'name': 'On or near Further/higher Educational Building'},
#    'longitude': '-1.621451'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '7d880473b37129f525ffc299782e465d415e5a2122ce17881ccb1b2c941df0d0',
#   'id': 98908479,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'other-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.989927',
#    'street': {'id': 1026390, 'name': 'On or near Osborne Road'},
#    'longitude': '-1.604744'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'be969fa1bdb67aa4e92e4409c7bc961ad1ed17014573ad968726bde89d66f736',
#   'id': 98913282,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'other-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.992331',
#    'street': {'id': 1026296, 'name': 'On or near A188'},
#    'longitude': '-1.579245'},
#   'context': '',
#   'outcome_status': {'category': 'Investigation complete; no suspect identified',
#    'date': '2022-01'},
#   'persistent_id': 'e83f123aec7eaaf3675bb4f859c67eafb7cc5277d1d649ea1077ca018236cce3',
#   'id': 98909186,
#   'location_subtype': '',
#   'month': '2022-01'},
#  {'category': 'other-crime',
#   'location_type': 'Force',
#   'location': {'latitude': '54.979384',
#    'street': {'id': 1024422, 'name': 'On or near Sandyford Road'},
#    'longitude': '-1.609441'},
#   'context': '',
#   'outcome_status': {'category': 'Status update unavailable',
#    'date': '2022-05'},
#   'persistent_id': '06b97652a3ed26b1d65fee10e503f08f62fdbf9b632b29bca9c1752bc0b55cc5',
#   'id': 98905259,
#   'location_subtype': '',
#   'month': '2022-01'}]

# %%
import requests

months=['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

crimerateslondon=[]

for month in months:
    url = 'https://data.police.uk/api/crimes-street/all-crime?lat=51.5307106&lng=-0.1274346&date=2021-'+month+''
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()  # Assuming the re

# %%
import requests
import pandas as pd

months = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']
crimerateslondon = []

for month in months:
    url = f'https://data.police.uk/api/crimes-street/all-crime?lat=51.5307106&lng=-0.1274346&date=2021-{month}'
    response = requests.get(url)
    
    if response.status_code == 200:
        # Assuming the API response is a list of dictionaries
        data_for_month = response.json()
        crimerateslondon.extend(data_for_month)

# Creating a DataFrame
crimeratemostpopular = pd.DataFrame(crimerateslondon)

# Display the DataFrame
crimeratemostpopular.to_csv('../Data/crimerates_most_popular.csv', index=False)

crimeratemostpopular
# Out:
#                     category location_type  \
# 0      anti-social-behaviour         Force
# 1      anti-social-behaviour         Force
# 2      anti-social-behaviour         Force
# 3      anti-social-behaviour         Force
# 4      anti-social-behaviour         Force
# ...                      ...           ...
# 26221            other-crime         Force
# 26222            other-crime         Force
# 26223            other-crime         Force
# 26224            other-crime         Force
# 26225            other-crime         Force
#
#                                                 location context  \
# 0      {'latitude': '51.538644', 'street': {'id': 964...
# 1      {'latitude': '51.530647', 'street': {'id': 960...
# 2      {'latitude': '51.527795', 'street': {'id': 960...
# 3      {'latitude': '51.527795', 'street': {'id': 960...
# 4      {'latitude': '51.538525', 'street': {'id': 964...
# ...                                                  ...     ...
# 26221  {'latitude': '51.523313', 'street': {'id': 960...
# 26222  {'latitude': '51.540253', 'street': {'id': 964...
# 26223  {'latitude': '51.542881', 'street': {'id': 964...
# 26224  {'latitude': '51.524190', 'street': {'id': 960...
# 26225  {'latitude': '51.536228', 'street': {'id': 964...
#
#                                           outcome_status  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 26221  {'category': 'Investigation complete; no suspe...
# 26222  {'category': 'Investigation complete; no suspe...
# 26223  {'category': 'Investigation complete; no suspe...
# 26224  {'category': 'Formal action is not in the publ...
# 26225  {'category': 'Investigation complete; no suspe...
#
#                                            persistent_id        id  \
# 0                                                         89873745
# 1                                                         89873750
# 2                                                         89873448
# 3                                                         89873449
# 4                                                         89873457
# ...                                                  ...       ...
# 26221  9587c440b5523b24189ee56d001685c8fb0783c30f651a...  97674942
# 26222  15452f31c3b85429af29e62a5c4336d184aebe0656f6e8...  97711398
# 26223  071c8923de69a87dc34302c8807cb863b254fc99713e27...  97647244
# 26224  53f791e4f37326e6e4bbccad6c0c5080fce5fe1bab3eb5...  98040809
# 26225  3297d97070c34a833b93aa17006d24686db8099afea632...  97671647
#
#       location_subtype    month
# 0                       2021-01
# 1                       2021-01
# 2                       2021-01
# 3                       2021-01
# 4                       2021-01
# ...                ...      ...
# 26221                   2021-12
# 26222                   2021-12
# 26223                   2021-12
# 26224                   2021-12
# 26225                   2021-12
#
# [26226 rows x 9 columns]

# %%
crimecategorylondon2022 = crimeratemostpopular['category'].value_counts().reset_index()
crimecategorylondon2022.columns = ['category', 'count']


crimecategorylondon2022.to_csv('../Data/crimecategorylondon2022.csv', index=False)

crimecategorylondon2022
# Out:
#                  category  count
# 0   anti-social-behaviour   7044
# 1           violent-crime   4471
# 2             other-theft   3333
# 3   theft-from-the-person   3014
# 4            public-order   1728
# 5                   drugs    998
# 6           vehicle-crime    975
# 7                burglary    945
# 8           bicycle-theft    938
# 9   criminal-damage-arson    911
# 10            shoplifting    851
# 11                robbery    752
# 12            other-crime    157
# 13  possession-of-weapons    109

# %%
import altair as alt
import pandas as pd

chart = alt.Chart(crimecategorylondon2022).mark_bar().encode(
    x='count:Q',
    y=alt.Y('category:N', sort='-x'),
    tooltip=['category:N', 'count:Q'] 
).properties(
    title='Crime by Category in London 2021'  # Add a title to the chart
)



chart
# Out:
# alt.Chart(...)
